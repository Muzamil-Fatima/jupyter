# %%
Simple Percetron with
Real values as input 
Weights
Loss calculation
Updating weights

# %%
import numpy as np

# %%
### Input to the percepron

# %%
features = np.array([[0,0],[0,1],[1,0],[1,1]])

# %%
#Label for the input

# %%
#target lables
labels = np.array([0,0,0,1])

# %%
Initilization of weight

# %%
w=[0.9, 0.9]

# %%
# no. of instances in feature array
features.shape[0]

# %%
labels

# %%
#print all the features or input data
for i in range(0, features.shape[0]):
    print(features[i])

# %%
lets define the instances as x1 and x2

# %%
for i in range(0, features.shape[0]):
    instances=(features[i])
    x1= instances[0]
    x2=instances[1]

    sum = x1 * w[0] + x2 * w[1]

    if sum > threshold:
        output=1 # output means the prediction
    else:
        output=0
        print("The Prediction is =", output)

# %%
for i in range(0, features.shape[0]):
    instances=(features[i])
    x1= instances[0]
    x2=instances[1]

    sum = x1 * w[0] + x2 * w[1]

    if sum > threshold:
        output=1 # output means the prediction
    else:
        output=0
        print("The Prediction is =", output, "", "Whereas the actual values are =", labels[i])

# %%
Calculate the Loss

# %%
for i in range(0, features.shape[0]):
    actual = labels[i]  # actual values
    instances = (features[i])

    x1 = instances[0]
    x2 = instances[1]

    sum= x1 * w[0] + x2* w[1]
    if sum > threshold:
        output=1 #output means the prediction
    else:
        output=0

    loss = actual - output
    print("The prediction is =" , output,"Whereas the actual value are = ", actual, "and loss of the Network", loss

# %%
if loss is 0 network is ok, otherwise we have to update the weights

# %%
#Update the weights (we need learning rate value)

# %%
learning_rate =0.1

# %%
for i in range(0, features.shape[0]):
    actual = labels[i]  # actual values
    instances = (features[i])

    x1 = instances[0]
    x2 = instances[1]

    sum= x1 * w[0] + x2* w[1]
    if sum > threshold:
        output=1 #output means the prediction
    else:
        output=0

    loss = actual - output
    # print("The prediction is =" , output,"Whereas the actual value are = ", actual, "and loss of the Network", loss
    #updating weights
    w[0] = w[0] +loss * learning_rate
    w[1] = w[1] + loss * learning_rate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for i in range(0, features.shape[0]):
#       2     actual = labels[i]  # actual values
#       3     instances = (features[i])
#
# NameError: name 'features' is not defined

# %%
How to show the effect of updated weight?
We have to run the network for another iteration(Concept of training)

# %%
epoch=5

# %%
Concept of epocs and training of the network

# %%
for j in range(0, epoch):
    print("epoch", j)
    for i in range(0, features.shape[0]):

    actual=labels[i]
    instances=(features[i])

    x1= instances[0]
    x2= instances[1]

    sum= x1 * w[0] + x2* w[1]

    if sum ?threshold:
        output= 1
    else:
        output=0
    loss =actual - output
    print("The Prediction is =", output, "Whereas the actual value are = ", actual, "and loss of the Network", loss ", 

    #updating weights
    w[0] = w[0] +loss* learning_rate
    w[1] = w[1]+loss * learing_rate

    print("..................")

# %%
from epocs 3 all prediction are correct
so we should to terminate the learning at epoch

# %%
import numpy as np

# %%
features= np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

# %%
labels = [0, 0, 0, 1]

# %%
for i in range(0, features.shape[0]):
    actual=labels[i] # actual values
    instances= (features[i])

    x1= instances[0]
    x2= instances[1]

    sum_unit= x1* w[0] + x1* w[1]

    if sum_unit > threshold:
        fire = 1
    else:
        fire = 0
    delta = actual - fire
    global_delta = global_delta + delta

    print("Prediction:", fire, "whereas actual  ", actual, "(error:

    w[0] = w[0] + delta * learning_rate
    w[1] = w[1] + delta * learning_rate

    print("..........")

    if global_delta == 0:
        break

# %%
pg# 741 end
