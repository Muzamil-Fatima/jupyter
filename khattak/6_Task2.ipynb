# %%
# pg #764 to 785

# %%
import numpy as np

# %%
Step 01: initialize inputs, weights and bias

# %%
# x1_feature = 0.7
# x2_fetaure = 0.3

input_features = np.array([0.7, 0.3])

weight_1 = 0.5
weight_2 = 0.5

weights = np.array([0.5, 0.3])

bias_value = 0.1

# %%
step02: Caculate weighted sum

# %%
weighted_sum=x1_feature * weight_1 + x2_feature * weight_2

weighted_sum = np.dot([input_features, weights) + bias_value

# %%
Step3:Calculate output

# %%
output = weighted_sum + bias_value

# %%
Step04:PRINT the value of inputs, weights, bias and output

# %%
TAsk-02 
Use user defined inputs, weights and bias write a code for single perceptron and apply activation function. (Apply Sigmoid activation function on dot product of weight and input value and add the bias value then apply activation function and show the output)
    Display input, weight, bias value and final output.

# %%
image

# %%
Step01 : Import Libarary
Step02 : User defined inputs, weights and bias
Step03: Calculate weighted sum
Step04: Define Sigmoid Function
Step04-a Define Step function
Step05: Apply  activation function on weighted_sum
Step06: Display input, weight, bias and final output

# %%
import numpy as np

# %%
inputs = [1, 2, 1.5]

weights = [0.5, 0.5, -0.5]
bias= 2

# %%
Step03: Calculate weighted sum

# %%
weighted_sum= np.dot(inputs, weights) + bias

# %%
Step04: Define Sigmoid function

# %%
def sigmoid(x):
    return(1/1 + np.exp(-x))

# %%
def single_preceptron(inputs, weights, bias):
    dot_product = np.dot(inputs, weights) + bias

    output = sigmoid(dot_product)
    return output

# %%
Step04-a Define Step Funcion

# %%
def step_function(x):
    return 1 if x > 0 else 0

# %%
Step05:Apply activation function on weighted_ sum

# %%
sigmoid_output = sigmoid(weighted_sum)

# %%
print("input features are ")
print("input value:", inputs)

print("\nThe weights for the input features")
print("\The respective weights values are:" , weights)

print("Input Bias for Network model is = ", bias)

print("\nThe dot product of inputs * weights * bias=")
print("the dot product is =", weighted_sum)

print("\n FInal output or Prediction using sigmoid activation function")
print("sigmoid output=", sigmoid_output)

print("\n Final output or Prediction using step function")
print("sigmoid output=", step_output)

# %%
Step06: Display input, weight, bias and final output
