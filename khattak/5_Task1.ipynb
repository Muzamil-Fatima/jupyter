# %%
# pg# 751 to 763

# %%
# Task-01

# %%
#Initialize input(features) values, weights and bias and show output.

# %%
### Give inputs, weights and bias value to single neuron(perceptron) and show the output, don't generate random weights and bias
#Display input, weight, bias value and final output.

# %%
# step 01 Initialization inputs weights and bias
# step 02 Calculate weighted sum
# step 03 Calculate output

# %%
# step 01 Initialization inputs weights and bias
x1_feature = 0.7
x2_feature = 0.3

weight_1 = 0.5
weight_2 = 0.3

# %%
# step 02 Calculate weighted sum
weighted_sum=x1_feature * weight_1 + x2_feature * weight_2

# %%
# step03: Caculate output
output = weighted_sum + bias_value

# %%
#step 04 PRINT the values of input, weights bias and output

# %%
print("Input values /features for the Perceptron")
print("x1_feature", x1_feature)
print("x2_feature", x2_fesature)
print("/nWeights of the percentron for the inputs values")
print("Weight fo first feature", weight_1)
print("Weight fo second feature", weight_2)

print("\nbias value for the perceptron")
print("the bias of the perceptron", bias_value)

print("The output of the perceptron without using activation function")
print("the output is ", output)
