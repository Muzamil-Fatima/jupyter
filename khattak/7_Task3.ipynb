# %%
# pg # 786 to 797

# %%
# Task3

# %%
### GEnerate the value of weight and bais randomly and genrate a code for percenptron and apply  activation function for single layer neuron. 
### Display input, weight, bias value and final output.

# %%
# For the below image ........ if we run again the pice of code the value of weights and baias should be change, beause we are using random weight and bias here

# %%
# image insert kro

# %%
# Step01 Import Library and set three inputs

# %%
import numpy as np
# User defined inputs
imputs = np.array([0.7, 0.3, 0.6])

# %%
# Step02:Use random weights and bias

# %%
# Generate random weights and bias
weights = np.random.rand(3)
bias = np.random.rand()

# %%
def ini_parameters(inputs):
    weights = np.random.rand(inputs)

    bias = np.random.rand()
    return weights, bias

# %%
# Step03: Define Sigmoid function
# Define the sigmoid activation function
def sigmoid (x):
    return 1/1 + np.exp(-x)

# %%
def single_perceptron(inputs, weights, bias):
    dot_product = np. dot(inputs, weights ) + bias

# %%
# Step04: Find weighted sum and apply non linear activation function

# %%
# Calculate the weighted sum (dot product) + bias
weighted_sum = np.dot(inputs, weights) +bias
# Apply the activation function on the weighted_sum
output = sigmoid (weighted_sum)

# %%
# Step05: PRINT inputs, weights, bias and output

# %%
#Display input, weight, bias, and final output
print("Input value are = ", Inputs)
print("\nRandom weight are = ", weights)
print("\n Random bias value is =", bias)

print("The prediction is=" , output)
