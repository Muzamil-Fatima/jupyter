# %%
Practical Machine Learning Walkthrough

# %%
Scikit Learn tarining and testing model

# %%
Working with IRIS Dataset (Multiclass balanced Dataset)

# %%
### Loading the iria Data with Scikit-Learn

# %%
taken from the [UCI machine learning repository](http://archive.ics.uci.edu/ml/), which hosts many of the commonly used datasets that are useful for 
                                                                                                                                                 benchmarking machine learning algorithms -- a very popular resource for machine learning practioners and researchers. Conveniently, some of these datasets are already included in sckit-learn.
                                                                                                                                                     For example, scikit-learn has a very straightforward set of data on these iris species. The data consist of the following:
                                                                                                                                                     -Features in the Iris dataset:
                                                                                                                                                     1. sepal length in cm 
                                                                                                                                                     2. sepal with in cm 
                                                                                                                                                     3. petal length in cm 
                                                                                                                                                     4 petal width in cm 
                                                                                                                                                     - Target classes to predict: (3 Classes and 4 feature with equal sample)
                                                                                                                                                         -Total Sample = 150, 50 samples in each class 
                                                                                                                                                                       1. Irsis Setosa
                                                                                                                                                                       2. Iris Vericolour
                                                                                                                                                                       3. Iris Virginica
                                                                                                                                                        <img scr="petal_sepal.jpg alt="Sepal" style="width:50%;"/>
                                                                                                                                                         (Image:"Peatal-sepal", Licensed under CC BY_SA 3.0 via Wikimedia COmmons - https://commons.wikimedia.org/wiki/File:Oetal-sepal.jpg#/media/File:Petal-sepal.jpy)

# %%
Loading Dataset fron skLearn.dataset

# %%
from sklearn.datasets import load_iris
#save "bunch" object containing iris dataset and its attributes
iris = load_iris()
type(iris)

# %%
# Printing the shape (total no of sample, and features)

# %%
import numpy as np
import pandas as pd 
dfiris = pd.read_csv('isis.csv')
print(dfiris.shape)

# %%
### Total samples here is 149 instead of 150 and features are 5 instead of 4???? Wait

# %%
Displaying some sample data, without proper colum name

# %%
dfiris.head(3)

# %%
Information about the coulum

# %%
print(dfiris.info())

# %%
from sklearn.datasets import load_iris
iris = load_iris()
#print(iris)
print(iris.feature_names)
print(iris.target_names)
print("No of Rows and Coumns")
print(iris.data.shape)
#print(iris.data)

# %%
Now with full shape and proper colum name

# %%
import seaborn as sns
newiris = sns.load_dataset('iris', header=0, parse_dates=False)
newiris.shape

# %%
Now 4 Features and target class

# %%
newiris.head(3)
#newiris= newiris.drop('species', axis=1)
#newiris.head(3)
#X= newiris.data;

# %%
Data in The IRIS Dataset

# %%
print(iris.data)

# %%
How CLasses are represented

# %%
#print the encoding scheme for species: 0 = setosa, 1= versicollor, 2= virgini
print("Toal three classes in the dataset")
print(iris.target_names)
#print integers representing the species of the each observation 
print("Each class repressented 50 times")
print(iris.target)

# %%
check the types of the features and response

# %%
#check the types of the features and response
print(type(iris.data))
print(type(iris.target))

# %%
# check the shape of the features (first dimension= number of the observations(total no of samples), second dimensions = number of features)

# %%
# check the shape of the features (first dimension = number of observations, second dimensions = number of features)
print(iris.data.shape)
#check the shape of the response(signgle dimension matching the number of he observations)
print("total samples in 3 classes)
print(iris.target.shape)

# %%
#store faeture matrix in A 
# The features matrix is assumned to be two-dimenensioanl, ewith shape[n_samples
#(n_samples):the number of rows in the total number of flowers in the dataset
print("Store all the features in X set")
X = iris.data
print(X)

# %%
store response vector in "y" (Class labels)

# %%
# store response vector in "y"
y = iris.target
print("This is the representation of all the three classes")
print("Each class having 50 samples")
print(y)

# %%
showing some samples with 3-nearest neighbour

# %%
# %matplotlib inline 
import mglearn
mglearn.plots.plot_knn_classification(n_neighbors=3)

# %%
creating Knn model object

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
knn = KNeighorsClassifier(n_neighbors=1)
# print(knn)

# %%
#Training the model

# %%
knn.fit(X, y)

# %%
Prediction of Model

# %%
y_pred = knn.oredict(X)

# %%
Accuracy of Model(100%)

# %%
print(knn.score(X, y))
print(metrics.accuracy_score(y, y_pred))

# %%
Experimenting again

# %%
shapes of the dataset (No ofRows(samples), and no of columns(features))
#print(newiris);
X_iris=newiris.drop('species', axis=1)
print(X_iris.shape)

# %%
In X_iris we only store total no of samples and features without class lables

# %%
class labels will be stored in y_iris

# %%
y_iris= newiris['species']
print(y_iris.shape)

# %%
Dividing the Dataset into Training and testing set

# %%
70% samples will be in training and 30% samples will be in  testing set

# %%
from sklearn.model_selection import train_test_splot
X_train, X_test, y_train, y_test= train_test_split(X_iris, y_iris, stratify=y_iris, random_state=40, train_size=70)

# %%
How many samples in Training dataset

# %%
print(X_tain.shape)

# %%
print(y_train.shape)

# %%
Y-test contain 45 class label as in X_test

# %%
print(y_test.shape)

# %%
Model Creation ad training of the model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
knn= KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# %%
Prediction of model

# %%
y_pred=knn .predict(X_test)

# %%
Accuracy ofKNN on testing set

# %%
print('Accuracy ofKNN n-5, on the testing set: ', format(metrics.accuracy_score(y_test, y_pred)))

# %%
Accuracy of KNN on training set

# %%
y_pred=knn.predict(X_train)
print('Accuracy on KNN n_5 on the training set: ', format(metrics.accuracy_score(y_test, y_pred)))

# %%
Accuracy ofKNN on Training set

# %%
y_pred=knn.predict(X_train)
print('Accuracy on KNN n_5 on the training set:',format(metrics.accuracy_score(y_train, y_pred)))

# %%
Cross validation

# %%
#Crosss validation
from sklearn.model_selection import cross_val_score
score= cross_val_score(knn, X_iris, y_iris)
prin("Mean Cross-validation score:", score.mean())
type(score)
score= cross_val_score(knn, X_iris, y_iris, cv=5)
print("cross-validation score:", score)
